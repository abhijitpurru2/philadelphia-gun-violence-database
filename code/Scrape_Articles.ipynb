# %%
#Required Modules
import requests
import time
import urllib
import pandas as pd
from google.colab import files
from bs4 import BeautifulSoup
from collections import defaultdict

# %%
def collect_articles(user_key, query, language = "en", page = 1):

  """Returns JSON Dictionary of Articles returned 
  by call to API given user-defined query"""
  
  url = "https://free-news.p.rapidapi.com/v1/search"
  querystring = {"q": query, "lang": language, "page" : page}
  headers = {
    'x-rapidapi-host': "free-news.p.rapidapi.com",
    'x-rapidapi-key': user_key
    }
  response = requests.request("GET", url, headers=headers, params=querystring)
  response_dict = response.json()
  return response_dict

# %%
## Sanity Check - Get Response from API
user_key = "3470351912msh3ef2f617a7f2c46p1b9fc2jsnf25363f582a4"
query = 'shooting AND Philadelphia'
response = collect_articles(user_key, query)
print(response)
# Out:
# {'status': 'ok', 'total_hits': 389, 'page': 1, 'total_pages': 16, 'page_size': 25, 'articles': [{'title': 'Charlotte puts home win streak on the line against Philadelphia', 'author': 'The Associated Press', 'published_date': '2021-12-06 08:03:08', 'published_date_precision': 'full', 'link': 'https://apnews.com/article/nba-sports-charlotte-philadelphia-76ers-lamelo-ball-9701166fbc0d4e3b8342cce5fe33f478', 'clean_url': 'apnews.com', 'summary': 'Philadelphia 76ers (12-11, ninth in the Eastern Conference) vs. Charlotte Hornets (14-11, sixth in the Eastern Conference)Charlotte, North Carolina; Monday, 7 p.m. ESTFANDUEL SPORTSBOOK LINE: Hornets -5.5BOTTOM LINE: Charlotte hosts Philadelphia aiming to extend its five-game home winning streak.The Hornets have gone 10-6 against Eastern Conference opponents. Charlotte ranks third in the NBA with 26.3 assists per game led by LaMelo Ball averaging 8.3.The 76ers are 7-7 in Eastern Conference play. Philadelphia ranks seventh in the Eastern Conference shooting 35.', 'rights': 'apnews.com', 'rank': 377, 'topic': 'news', 'country': 'US', 'language': 'en', 'authors': ['The Associated Press'], 'media': 'https://storage.googleapis.com/afs-prod/media/afs:Medium:751921853724/700.png', 'is_opinion': False, 'twitter_account': '@ap', '_score': 20.339088, '_id': '4c6bf644d694b9efe6f1853c19c6cb37'}, {'title': 'Charlotte puts home win streak on the line against Philadelphia', 'author': 'The Associated Press', 'published_date': '2021-12-06 10:14:36', 'published_date_precision': 'full', 'link': 'https://www.thestar.com/sports/basketball/2021/12/06/charlotte-puts-home-win-streak-on-the-line-against-philadelphia.html', 'clean_url': 'thestar.com', 'summary': 'Philadelphia 76ers (12-11, ninth in the Eastern Conference) vs. Charlotte Hornets (14-11, sixth in the Eastern Conference)Charlotte, North Carolina; Monday, 7 p.m. EST FANDUEL SPORTSBOOK LINE: Hornets -5.5BOTTOM LINE: Charlotte hosts Philadelphia aiming to extend its five-game home winning streak.The Hornets have gone 10-6 against Eastern Conference opponents. Charlotte ranks third in the NBA with 26.3 assists per game led by LaMelo Ball averaging 8.3.The 76ers are 7-7 in Eastern Conference play.', 'rights': 'thestar.com', 'rank': 808, 'topic': 'news', 'country': 'CA', 'language': 'en', 'authors': ['The Associated Press'], 'media': 'https://www.thestar.com/assets/img/thestar-ribbon.png', 'is_opinion': False, 'twitter_account': '@TorontoStar', '_score': 20.332253, '_id': '052008596baf344fb096de31c4874797'}, {'title': '16-Year-Old Shot 8 Times In Deadly North Philadelphia Shooting Identified As Kanye Davis, Police Say', 'author': 'schneider, http://www.facebook.com/cbsphilly', 'published_date': '2021-11-29 09:15:38', 'published_date_precision': 'full', 'link': 'https://philadelphia.cbslocal.com/2021/11/29/kanye-davis-north-philadelphia-shooting-deadly-gun-violence-diamond-street-teen/', 'clean_url': 'cbslocal.com', 'summary': 'PHILADELPHIA (CBS) — A 16-year-old boy is dead after being shot eight times in North Philadelphia Sunday night, according to Philadelphia police. The victim was later identified as Kanye Davis, police say.The shooting happened in the 400 block of Diamond Street at 8 p.m.READ MORE: TSA Confiscates Loaded Handgun From Man At Philadelphia International AirportThe department said officers found the victim with eight gunshot wounds throughout the body inside a Nissan. He was pronounced dead at the hospital.', 'rights': 'cbslocal.com', 'rank': 421, 'topic': 'news', 'country': 'US', 'language': 'en', 'authors': ['schneider', 'http://www.facebook.com/cbsphilly'], 'media': 'https://philadelphia.cbslocal.com/wp-content/uploads/sites/15116066/2021/11/lns-Diamond-St-Shooting-112821_frame_4457.jpg?w=1500', 'is_opinion': False, 'twitter_account': 'CBSphilly', '_score': 20.23159, '_id': 'a0c18fdea31562bd12726a6636bec500'}, {'title': 'What We Know About 17-Year-Old Latif Williams, Wanted For Murder Of Temple Student Samuel Collington', 'author': 'schn ...

# %%
def extract_article_info(info, response):

  """ Returns dictionary of desired article info from
   1 page of API call response"""
   
  info_dict = defaultdict(list)
  articles = response['articles']
  for header in info:
    for article in articles:
      info_dict[header].append(article[header])
         
  return info_dict

# %%
## Sanity Check - Use collect_articles and extract_article_info to extract
## article info for each page of articles returned by API call
num_pages = response['total_pages']
i = 1
extracted_info = defaultdict(list)
while i <= num_pages:
  page_response = collect_articles(user_key, query, page = i)
  time.sleep(2)
  info_from_page = extract_article_info(['link', 'title', 'summary', 'published_date'], page_response)
  for key in info_from_page.keys():
    extracted_info[key] += info_from_page[key]
  i+=1

print(len(extracted_info['link']))
# Out:
# 389

# %%
def create_dataframe(info_dict, unwanted_topics = [], column_name = ''):

  """Returns dataframe with desired article information, allows user 
  to remove articles that contain keywords in a user-defined column"""
  
  import pandas as pd
  df = pd.DataFrame(info_dict)
  for topic in unwanted_topics:
    mask = [topic not in column_name for column_name in df[column_name]]
    df = df[mask]
  df.reset_index(inplace = True)
  df = df.drop(['index'], axis = 1)   

  return df

# %%
## Sanity Check - Create Dataframe of Article Information and
## remove articles that contain "76ers" in their summary
unwanted_topic = ["76ers"]
column_name = "summary"
df = create_dataframe(extracted_info, unwanted_topic, column_name)
print(df.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f395c4b14d4a> in <module>()
#       3 unwanted_topic = ["76ers"]
#       4 column_name = "summary"
# ----> 5 df = create_dataframe(extracted_info, unwanted_topic, column_name)
#       6 print(df.head)
#
# NameError: name 'create_dataframe' is not defined

# %%
def scrape_keywords(df):

  """Creates soup for each link in dataframe, then extracts keywords
  from each article"""
  
  i = 0
  master_keywords_list = ['']*len(df)
  while i < len(df):
    try: #some websites do not seem to allow scraping
      html_text = urllib.request.urlopen(df['link'][i]).read()
      soup = BeautifulSoup(html_text, 'html.parser')
      content = soup.find_all('meta')
      for line in content:
        keywords = []
        if ('name="keywords"' in str(line)):
          keywords = (str(line).split('"')[1].split(','))
          break 
        else:
          keywords = [] 

    except Exception as e:
      keywords = []
    
    
    master_keywords_list[i] = keywords
    i += 1
  df["keywords"] = master_keywords_list  
    
  
  return df

# %%
## Sanity Check- Scrape Keywords and add Column to df
df = scrape_keywords(df)
print(df.head(10))
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#                                                 link  ...                                           keywords
# 0  https://philadelphia.cbslocal.com/2021/11/29/k...  ...  [north philadelphia,  shooting,  deadly,  gun ...
# 1  https://philadelphia.cbslocal.com/2021/12/01/l...  ...  [latif williams,  samuel collington,  philadel...
# 2  https://www.chron.com/news/article/Philadelphi...  ...                                                 []
# 3  https://www.sfgate.com/news/article/Philadelph...  ...                                                 []
# 4  https://patch.com/pennsylvania/philadelphia/14...  ...                                                 []
# 5  https://philadelphia.cbslocal.com/2021/12/04/p...  ...  [philadelphia shooting,  philadelphia gun viol...
# 6  https://philadelphia.cbslocal.com/2021/12/05/p...  ...  [philadelphia shooting,  kensington shooting, ...
# 7  https://philadelphia.cbslocal.com/2021/12/04/p...  ...  [philadelphia shooting,  philly shooting,  law...
# 8  https://apnews.com/f7d61fa2a1666c7144099e9384a...  ...                                              [yes]
# 9  https://philadelphia.cbslocal.com/2021/12/01/p...  ...  [philadelphia,  gun violence,  ambush,  shooti...
#
# [10 rows x 5 columns]

# %%
def scrape_external_links(df):

  """Creates soup for each link in df and extracts the
  links that link to other news articles"""
  
  master_links_list = ['']*len(df)
  i=0
  while i < len(df):
    try: #some websites do not seem to allow scraping
      html_text = urllib.request.urlopen(df['link'][i]).read()
      soup = BeautifulSoup(html_text, 'html.parser')
      external_article_soup = soup.find_all('a', {'class' : 'bump-view' })
      external_links = set()
      for link in external_article_soup:
        if link not in external_links:
          external_links.add(link['href'])
      master_links_list[i] = external_links 
    except:
      master_links_list[i] = []  
    i+=1
  df["external_links"] = master_links_list  
  return(df)

# %%
## Sanity Check- Scrape Links and add Column to df
scrape_external_links(df)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#                                                   link  ...                                     external_links
# 0    https://philadelphia.cbslocal.com/2021/11/29/k...  ...  {https://philadelphia.cbslocal.com/2021/12/04/...
# 1    https://philadelphia.cbslocal.com/2021/12/01/l...  ...  {https://philadelphia.cbslocal.com/2021/12/04/...
# 2    https://www.chron.com/news/article/Philadelphi...  ...                                                 {}
# 3    https://www.sfgate.com/news/article/Philadelph...  ...                                                 {}
# 4    https://patch.com/pennsylvania/philadelphia/14...  ...                                                 {}
# ..                                                 ...  ...                                                ...
# 315  https://www.espn.com/nfl/story/_/id/32796117/n...  ...                                                 {}
# 316  http://www.espn.com/page2/s/greenberg/040414.html  ...                                                 {}
# 317      http://www.espn.com/page2/s/wiley/021018.html  ...                                                 {}
# 318  https://www.cbsnews.com/news/60-minutes-morley...  ...                                                 {}
# 319  http://www.espn.com/espn/eticket/story?page=10...  ...                                                 {}
#
# [320 rows x 6 columns]

# %%
def colab_to_excel(df, file_name = "data.xlsx"):

  """Downloads df as Excel spreadsheet"""

  df.to_excel(file_name)
  files.download(file_name)
  return 1

def colab_to_csv(df, file_name = "data.csv"):

  """Downloads df as CSV"""

  df.to_csv(file_name)
  files.download(file_name)
  return 1

# %%
## Sanity Check - Download excel spreadsheet and csv from Colab
colab_to_excel(df, "scraped_articles_with_keywords.xlsx")
colab_to_csv(df, "scraped_articles_with_keywords.csv")
# Out:
# 1
